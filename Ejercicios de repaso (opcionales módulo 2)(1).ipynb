# %% [markdown]
# # Ejercicios de repaso del módulo 2 (opcionales)
# Nota. En algunos ejercicios se piden operaciones matematicas como la raiz cuadrada, la potencia o realizar operaciones con el número PI, para ello se puede utilizar la librería math (import math) cuya documentación se encuentra a continuación: https://docs.python.org/3/library/math.html <br><br>
# __IMPORTANTE: Se recomienda realizar estos ejercicios cuando se haya terminado el módulo 2.__
#
# ## VARIABLES Y CONDICIONALES
# 1.	Pedir los coeficientes de una ecuación de 2º grado, y muestre sus soluciones reales. Si no existen, debe indicarlo.
# 2.	Pedir el radio de un círculo y calcular su área. A = PI * r^2.
# 3.	Pedir el radio de una circunferencia y calcular su longitud.
# 4.	Pedir dos números y decir si son iguales o no.
# ---------------------------------------------------------------
# 5.	Pedir un número e indicar si es positivo o negativo.
# 6.	Pedir dos números y decir si uno es múltiplo del otro.
# 7.	Pedir dos números y decir cuál es el mayor
# 8.	Pedir dos números y decir cuál es el mayor o si son iguales.
# 9.	Pedir dos números y mostrarlos ordenados de mayor a menor.
# 10.	Pedir tres números y mostrarlos ordenados de mayor a menor.
# 11.	Pedir un número entre 0 y 99.999 y decir cuántas cifras tiene.
# 12.	Pedir un número entre 0 y 99.999 y mostrarlo con las cifras al revés.
# 13.	Pedir un número entre 0 y 99.999 y decir si es capicúa o no.
# 14.	Pedir una nota de 0 a 10 y mostrarla en la forma: Insuficiente, Suficiente, Bien, Notable y Sobresaliente.
# 15.	Pedir el día, mes y año de una fecha e indicar si la fecha es correcta. Suponiendo todos los meses de 30 días.
# 16.	Pedir el día, mes y año de una fecha e indicar si la fecha es correcta. Con meses de 28, 30 y 31 días. Sin años bisiestos.
# 17.	Pedir el día, mes y año de una fecha correcta y mostrar la fecha del día siguiente. Suponer que todos los meses tienen 30 días.
# 18.	Ídem que el ejercicio 17 suponiendo que cada mes tienen un número distinto de días (suponer que febrero tiene siempre 28 días).
# 19.	Pedir dos fechas y mostrar el número de días que hay de diferencia. Suponiendo todos los meses de 30 días.
# 20.	Pedir una hora de la forma hora, minutos y segundos, y mostrar la hora en el segundo siguiente.
# 21.	Pedir una nota numérica entera entre 0 y 10, y mostrar dicha nota de la forma: CERO, UNO, DOS, TRES… (Esto en otro lenguajes se haría con switch, en Python no lo tenemos, pero hay alternativa)
# 22.	Pedir un número de 0 a 99 y mostrarlo escrito. Por ejemplo, para 56 mostrar: cincuenta y seis.
#
#
# ## CONDICIONALES Y BUCLES
#
# 23.	Leer un número y mostrar su cuadrado, repetir el proceso hasta que se introduzca un número negativo.
# 24.	Leer un número e indicar si es positivo o negativo. El proceso se repetirá hasta que se introduzca un 0.
# 25.	Leer números hasta que se introduzca un 0. Para cada uno indicar si es par o impar.
# 26.	Pedir números hasta que se teclee uno negativo, y mostrar cuántos números se han introducido.
# 27.	Pedir números hasta que se teclee un 0, mostrar la suma de todos los números introducidos.
# 28.	Pedir números hasta que se introduzca uno negativo, y calcular la media.
# 29.	Pedir un número N, y mostrar todos los números del 1 al N.
# 30.	Escribir todos los números del 100 al 0 de 7 en 7.
# 31.	Pedir 15 números y escribir la suma total.
# 32.	Diseña un programa que muestre el producto de los 10 primeros números impares.
# 33.	Pedir un número y calcular su factorial.
# 34.	Pedir 10 números. Mostrar la media de los números positivos, la media de los números negativos y la cantidad de ceros.
# 35.	Pedir 10 sueldos. Mostrar su suma y cuantos hay mayores de 1000€
# 36.	Dadas las edades y alturas de 5 alumnos, mostrar la edad y la estatura media, la cantidad de alumnos mayores de 18 años, y la cantidad de alumnos que miden más de 1.75
# 37.	Pide un número (que debe estar entre 0 y 10) y mostrar la tabla de multiplicar de dicho número.
# 38.	Una empresa que se dedica a la venta de desinfectantes necesita un programa para gestionar las facturas. En cada factura figura: el código del artículo, la cantidad vendida en litros y el precio por litro. Se pedirán 5 facturas, tras las cuales se mostrará: Facturación total, cantidad en litros vendidos del artículo 1 y cuantas facturas se emitieron de más de 600€.
# 39.	Igual que el anterior, pero suponiendo que no se introduce el precio por litro. Solo existen tres productos con precios:
#     * 1-	0.6€/litro
#     * 2-	3€/litro
#     * 3-	1.25€/litro
# 40.	Dadas 6 notas, escribir la cantidad de alumnos aprobados, condicionados (=4) y suspensos.
# 41.	Pedir un número N, introducir N sueldos, y mostrar el sueldo máximo.
# 42.	Pedir 10 números, y mostrar al final si se ha introducido alguno negativo.
# 43.	Pedir 5 calificaciones de alumnos y decir al final si hay algún suspenso.
# 44.	Pedir 5 números e indicar si alguno es múltiplo de 3.
#
#
# ## BUCLES ANIDADOS
#
# 45.	Realizar detenidamente una traza al siguiente programa y muestra cual sería la salida por pantalla:
# <br>_Nota: Forma de leer el para (bucle for): desde i siendo 1 hasta i siendo 4 (y si no se dice nada del incremente, se asumen que es el incremento normal de i=i+1)_
# <br>_Nota 2: El simbolo <- es un = en pseudocódigo_
# ![1.png](attachment:1.png)
#
# 46.	Realiza una traza del siguiente algoritmo y muestra la salida generada por pantalla:
# ![2.png](attachment:2.png)
#
# 47.	Diseñar una aplicación que muestre las tablas de multiplicar del 1 al 10.
# 48.	Dibuja un cuadrado de n elementos de lado utilizando *.
# 49.	Necesitamos mostrar un contador con 5 dígitos (X-X-X-X-X), que muestre los números del 0-0-0-0-0 al 9-9-9-9-9, con la particularidad que cada vez que aparezca un 3 lo sustituya por una E.
# 50.	Realizar un programa que nos pida un número N, y nos diga cuantos números hay entre 1 y N que son primos
#
#
# ## LISTAS
#
# 51.	Leer 5 números y mostrarlos en el mismo orden introducirlo.
# 52.	Leer 5 números y mostrarlos en orden inverso al introducirlos.
# 53.	Leer 5 números por teclado y a continuación realizar la media de los números positivos, la media de los negativos y contar el número de ceros.
# 54.	Leer 10 números enteros. Debemos mostrarlos en el siguiente orden: el primero, el último, el segundo, el penúltimo, el tercero, etc.
# 55.	Leer por teclado dos listas de 10 números enteros y mezclarlas en una tercera lista de la forma: el 1º de A, el 1º de B, el 2º de A, el 2º de B, etc.
# 56.	Leer los datos correspondientes a dos listas de 12 elementos numéricos, y mezclarlos en una tercera lista de la forma: 3 de la lista A, 3 de la lista B, otros 3 de A, otros 3 de B, etc.
# 57.	Leer por teclado una serie de 10 números enteros. La aplicación debe indicarnos si los números son todos iguales, si están ordenados de forma creciente, decreciente, o si están desordenados.
# 58.	Diseñar una aplicación que declare una lista de 10 elementos enteros. Leer mediante el teclado 8 números. Después se debe pedir un número y una posición, insertarlo en la posición indicada, desplazando los que estén detrás.
# 59.	Crear un programa que lea por teclado una lista de 10 números enteros y la desplace una posición hacia abajo: el primero pasa a ser el segundo, el segundo pasa a ser el tercero y así sucesivamente. El último pasa a ser el primero.
# 60.	Ídem que el anterior, pero desplazar N posiciones, siendo N un número introducido por el usuario.
# 61.	Leer 5 elementos numéricos que se introducirán ordenados de forma creciente. Éstos los guardaremos en una lista de tamaño 10. Leer un número N, e insertarlo en el lugar adecuado para que la lista continúe ordenado.
# 62.	Leer por teclado una lista de 10 elementos numéricos enteros y una posición (entre 0 y 9). Eliminar el elemento situado en la posición dada sin dejar huecos.
# 63.	Leer 10 elementos numéricos que se introducirán en una lista. Guardar en otra lista los elementos pares primero, y a continuación los elementos impares.
# 64.	Leer dos series de 10 enteros (y almacenarlos en sendas listas), que estarán ordenadas crecientemente. Copiar (fusionar) las dos listas en una tercera lista, de forma que sigan ordenados.
# 65.	Leer 10 enteros ordenados crecientemente. Leer N y buscarlos en la lista. Se debe mostrar la posición en que se encuentra. Si no está, indicarlo con un mensaje.
# 66.	Queremos desarrollar una aplicación que nos ayude a gestionar las notas de un centro educativo. Cada grupo (o clase) está compuesto por 5 alumnos. Se pide leer las notas del primer, segundo y tercer trimestre de un grupo. Debemos mostrar al final: la nota media del grupo en cada trimestre, y la media del alumno que se encuentra en la posición N (N se lee por teclado)
#
# ## LISTAS N-DIMENSIONES
#
# 67.	Crear una lista bidimensional de tamaño 5x5 y rellenarla de la siguiente forma: la posición T[n,m] debe contener n+m. Después se debe mostrar su contenido.
# 68.	Crear y cargar una lista de tamaño 4x4 y decir si es simétrica o no, es decir si se obtiene la misma lista al cambiar las filas por columnas.
# 69.	Crear y cargar dos listas de 3x3, sumarlas y mostrar su suma.
# 70.	Crear y cargar una lista de 3x3, tasnsponerla y mostrarla.
# 71.	Crear una lista de 7x7 y rellenarla de forma que los elementos de la diagonal principal sean 1 y el resto 0.
# 72.	Crear y cargar una lista de 10x10, mostrar la suma de cada fila y de cada columna.
# 73.	Utilizando dos listas de tamaño 5x9 y 9x5, cargar la primera y transponerla en la segunda.
# 74.	Crear una matriz “marco” de tamaño 8x6: todos sus elementos deben ser 0 salvo los de los bordes que deben ser 1. Mostrarla.
# 75.	Hacer lo mismo que el ejercicio anterior, pero con una matriz de 9x9x9. Creamos un cubo con las caras puestas a 1 y el interior a 0.
# 76.	El siguiente programa pide una serie de datos y tras procesarlos ofrece unos resultados por pantalla. Mostrar el resultado:
# ![3.png](attachment:3.png)
#
#
# 77.	El siguiente programa pide una serie de datos y tras procesarlos ofrece unos resultados por pantalla. Mostrar el resultado:
# ![4.png](attachment:4.png)
#
# 78.	Se pretende realizar un programa para gestionar la lista de participaciones en una competición de salto de longitud. El número de plazas disponible es de 10. Sus datos se irán introduciendo en el mismo orden que vayan inscribiéndose los atletas. Diseñar el programa que muestre las siguientes opciones:
#     * 1.	Inscribir un participante.
#     * 2.	Mostrar listado de datos.
#     * 3.	Mostrar listado por marcas.
#     * 4.	Finalizar el programa.
#
# <br>Si se selecciona 1, se introducirán los datos de uno de los participantes: Nombre, número de dorsal, mejor marca del 2020, mejor marca del 2019 y mejor marca del 2018.
# Si se elige la opción 2, se debe mostrar un listado por número del dorsal.
# La opción 3 mostrará un listado ordenado por la marca del 2020, de mayor a menor.
# Tras procesar cada opción, se debe mostrar de nuevo el menú inicial, hasta que se seleccione la opción 4, que terminará el programa.
#
#
# ## FUNCIONES
#
# 79.	Realizar una función, a la que se le pase como parámetro un número N, y muestre por pantalla N veces, el mensaje “Módulo ejecutándose”
# 80.	Diseñar una función que tenga como parámetros dos números, y que calcule el máximo.
# 81.	Ídem una versión que calcule el máximo de 3 números.
# 82.	Ídem una versión que calcule el máximo de una lista de N elementos.
# 83.	Función a la que se le pasan dos enteros y muestra todos los números comprendidos entre ellos inclusive.
# 84.	Función que muestra en pantalla el doble del valor que se le pasa como parámetro.
# 85.	Realizar una función que calcule (muestre en pantalla) el área o el volumen de un cilindro, según se especifique. Para distinguir un caso de otro se le pasará el carácter ‘a’ para área o ‘v’ para volumen. Además, hemos de pasarle a la función el radio y la altura.
# 86.	Ídem que devuelva una lista con el área y el volumen.
# 87.	Función al que se le pase un número entero y devuelva el número de divisores primos que tiene.
# 88.	Ídem diseñar una función que devuelve una lista con los divisores.
# 89.	Escribir una función que calcule el máximo común divisor de dos números.
# 90.	Ídem con tres números.
# 91.	Ídem con una lista.
# 92.	Función que calcule el mínimo común múltiplo de dos números.
# 93.	Ídem con tres números.
# 94.	Ídem con una lista.
# 95.	Función que decida si dos números enteros positivos son amigos. Dos números son amigos, si la suma de sus divisores (distintos de ellos mismos) son iguales.
# 96.	Diseñar una función que decida si un número es primo.
# 97.	Diseñar una función que calcule A elevado a N.
# 98.	Diseñar una función que muestre en binario un número entre 0 y 255.
# 99.	Diseñar una función que sume los N primeros números impares.
# 100.	Dado el valor de un ángulo, sería interesante saber su seno, coseno y tangente. Escribir una función que muestre en pantalla los datos anteriores.
# 101.	Diseñar una función que calcule la distancia euclídea de dos puntos.
# 102.	Diseñar una función a la que se le pasa como parámetro una lista que debe rellenar. Se leerá por teclado una serie de números: guardaremos solo los pares e ignoraremos los impares. También hay que devolver la cantidad de impares ignorados.
# 103.	Diseñar una función a la que se le pase una lista de enteros y un número. Debemos buscar el número en la lista e indicar si se encuentra o no.
# 104.	Igual que el ejercicio anterior, pero suponiendo que la lista no esté siempre llena, y el número de elementos se pasa también como parámetro.
# 105.	Diseñar la función opera_tabla, a la que se le pasan dos listas, el número de elementos útiles y que operación se desea realizar: sumar, restar, multiplicar o dividir (mediante un carácter: ‘s’, ‘r’, ‘m’, ‘d’). La función debe devolver una lista con los resultados.
# 106.	Diseñar una función que ordene una lista que se le pase por parámetro.
# 107.	Diseñar una función que tome como parámetro dos listas. El primero con los 6 números de una apuesta de la primitiva, y la segunda con los 6 números ganadores. La función debe devolver el número de aciertos.
# 108.	Diseñar una función que calcule el factorial de N recursivamente.
# 109.	Diseñar una función que calcule el valor máximo de una lista de forma recursiva.
# 110.	Diseñar una función que realice una búsqueda dicotómica en una lista, de forma recursiva.
